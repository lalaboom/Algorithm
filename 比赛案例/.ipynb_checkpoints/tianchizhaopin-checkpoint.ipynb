# %% [markdown]
# [第二届阿里巴巴大数据智能云上编程大赛](https://tianchi.aliyun.com/competition/entrance/231728/introduction)
#
# Baseline

# %%
# !mkdir -p GuodongDrive
# !google-drive-ocamlfuse GuodongDrive

# %%
import os
os.chdir("GuodongDrive")
# !ls
# Out:
#  aclImdb_v1.tar.gz	 sensePY.ipynb
#  data_description.txt	'Sentiment Analysis on Movie Reviews'
#  drive			'Spooky Author Identification'
#  GuodongDrive		 submission.csv
#  House			 test.csv
# 'House price'		 testData.tsv
#  Houseprice.ipynb	 Titanic
#  huawei			 torchtest.ipynb
#  labeledTrainData.tsv	 train.csv
# 'movie review'		 Untitled0.ipynb
#  neg			 word_to_vec
#  O2O			 XGboost_practice1.ipynb
#  practice		 XGboost_practice2.ipynb
#  residual_plot.png	 Yi
#  Sales			 zhaopin
#  sample_submission.csv	 剑指offer
#  Sense1.ipynb		 数组和链表.desktop
#  Sense2.ipynb（副本）	 时序
#  Sense.ipynb		 糖尿病数据.txt

# %%
os.chdir("zhaopin")
# !ls
# Out:
# table1_user	 user_ToBePredicted
# table2_jd	 zhaopin_round1_submit_20190716.csv
# table3_action	 zhaopin_round1_user_exposure_A_20190723.csv
# Untitled0.ipynb

# %% [markdown]
# #导入库和数据

# %%
import pandas as pd
import numpy as np
from functools import partial
pd.set_option("max_column",200)

# %%
train_user = pd.read_csv("table1_user",delimiter="\t")
test_user = pd.read_csv("user_ToBePredicted",delimiter="\t")
test_action = pd.read_csv("zhaopin_round1_user_exposure_A_20190723.csv",delim_whitespace=True)
train_job = pd.read_csv("table2_jd",delimiter="\t",error_bad_lines=False)
train_action = pd.read_csv("table3_action",delimiter="\t")
# Out:
# b'Skipping line 173315: expected 18 fields, saw 20\n'
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #看一下数据

# %%
train_user.head(2)
# Out:
#                             user_id  live_city_id desire_jd_city_id  \
# 0  17e1b9f107dd1214bd78dec6d91593a4           551           551,-,-
# 1  0c02d9411e83ae0308cdc40700385d4c           763           763,-,-
#
#   desire_jd_industry_id desire_jd_type_id  desire_jd_salary_id  \
# 0          房地产/建筑/建材/工程          工程造价/预结算            100002000
# 1                    其他               化妆师            400106000
#
#   cur_industry_id    cur_jd_type cur_salary_id cur_degree_id  birthday  \
# 0    房地产/建筑/建材/工程  土木/建筑/装修/市政工程    0200104000            大专        24
# 1    房地产/建筑/建材/工程           后期制作    0400106000            大专        24
#
#   start_work_date                                         experience
# 0            2017  停车|现场|凤凰|预算编制|建设|实习|专家|公园|预算软件|勘察|合同|知识|商务|单位|...
# 1            2015                              调色员|彩妆|护肤|布料|光源|客户|调色

# %% [markdown]
# **期望薪资是10位或者12位（遇到9位或者11位前面或者后面补0，超过上面列表部分为脏数据）**

# %%
test_user.head(2)
# Out:
#                             user_id  live_city_id desire_jd_city_id  \
# 0  0749d9a864562008d1f61fc9d14e1d28           531           531,-,-
# 1  121cc4b0ea96666856c58ee25c2d945e           576       530,576,854
#
#                  desire_jd_industry_id          desire_jd_type_id  \
# 0  大型设备/机电设备/重工业,房地产/建筑/建材/工程,电气/电力/水利  项目经理/项目主管,房地产项目管理,项目专员/助理
# 1               房地产|建筑业,文化|传媒|娱乐|体育,环保     建筑制图,三维/3D设计/制作,设计管理人员
#
#    desire_jd_salary_id cur_industry_id  cur_jd_type cur_salary_id  \
# 0            600108000   大型设备/机电设备/重工业    项目管理/项目协调    0400106000
# 1                    0    房地产/建筑/建材/工程  影视/媒体/出版/印刷    0800110000
#
#   cur_degree_id  birthday start_work_date  \
# 0           NaN        24            2016
# 1            本科        27            2012
#
#                                           experience
# 0  互联网参考模型osi七层|文件|材料|项目管理|成本分析|风险|材料采购|工程部|保证|成本...
# 1  三维|pr|ps|现场|bim|模型|建设|处理|知识|钢结构|施工人员|变更|动画|视频|...

# %%
test_action.head(2)
# Out:
#                             user_id                             jd_no
# 0  035b5c8e977d2f76628d9b7edfc95323  669576ca43ff7b2b6f5bc97a3dfeda9e
# 1  035b5c8e977d2f76628d9b7edfc95323  2fc7d27894fe1776e7b76546deb8ae5d

# %% [markdown]
# **job_no 为职位代码**

# %%
train_job.head(2)
# Out:
#                               jd_no jd_title company_name  city jd_sub_type  \
# 0  3cf395f1d6f12de112d118c0349acbcd  景观主创设计师            -   530     园林/景观设计
# 1  4ce99de185f55bea127ccd74c4bbf0ad  土建工程造价员            -   551    工程造价/预结算
#
#    require_nums  max_salary  min_salary start_date  end_date  is_travel  \
# 0             2       25000       15000   20190325  20190524          1
# 1             5        8000        4000   20190313  20190412          1
#
#    min_years  key min_edu_level max_edu_level is_mangerial  \
# 0        510  NaN            本科            \N           \N
# 1        305  NaN           大专             \N           \N
#
#   resume_language_required                                    job_description
# 0                       \N  岗位职责：1、全面负责景观项目的概念设计和方案设计、扩初设计和施工图设计的工作，同时对方案文...
# 1                      NaN  1、能够独立完成工程概、预、结算的编制及审核工作；2、熟悉重庆地区相关计价原则及计价文件；3...

# %% [markdown]
# 字段	字段说明
#
# jd_no	职位代码
#
# jd_title	职位标题
#
# company_name	公司
#
# city	城市
#
# jd_sub_type	职位子类
#
# require_nums	需求人数
#
# max_salary	最高月薪
#
# min_salary	最低月薪
#
# start_date	开始日期
#
# end_date	结束日期
#
# is_travel	是否要求出差
#
# min_years	工作年限（103:一年到三年，305:三年到五年，510:五年到十年，1099:十年以上）
#
# key	关键字
#
# min_edu_level	最低学历
#
# max_edu_level	最高学历
#
# is_mangerial	是否要求管理经验
#
# resume_language_required	语言需求
#
# job_description	职位描述

# %%
train_action.head(7)
# Out:
#                             user_id                             jd_no  \
# 0  17e1b9f107dd1214bd78dec6d91593a4  4ce99de185f55bea127ccd74c4bbf0ad
# 1  17e1b9f107dd1214bd78dec6d91593a4  e9959d3b5fd8b26da07e8b8a3b80489a
# 2  17e1b9f107dd1214bd78dec6d91593a4  7ecd6ab0c7e43b40b7d1dbd4a9b1e6f5
# 3  17e1b9f107dd1214bd78dec6d91593a4  112ea9c8ef92c1a7d5fa679cc6c05053
# 4  17e1b9f107dd1214bd78dec6d91593a4  1953082bf7ee0919820eb7ba05be3425
# 5  17e1b9f107dd1214bd78dec6d91593a4  dda657439fe72a592b523596453f0290
# 6  17e1b9f107dd1214bd78dec6d91593a4  78a36854fa6e42df58bf292f91477031
#
#    browsed  delivered  satisfied
# 0        0          0          0
# 1        0          0          0
# 2        0          0          0
# 3        0          0          0
# 4        0          0          0
# 5        1          0          0
# 6        0          0          0

# %% [markdown]
# 行为表 table3_action：
#
# 字段	字段说明
#
# user_id	用户标识
#
# jd_no	职位代码
#
# browsed	是否浏览
#
# delivered	是否投递
#
# satisfied	HR是否认可

# %% [markdown]
# 行为表表示的是当为简历投放相应岗位后的行为，其中satisfied为1表示HR认可，delivered为1表示已经投递，browsed为1表示预览。
#
# 评估数据表为 user_ToBePredicted和user_exposure，其中user_ToBePredicted是需要预测的简历的详细信息（具体meta参见训练数据table1_user），user_exposure是user_ToBePredicted中每个简历被曝光的岗位。其中，user_exposure表：
#
# 字段	字段说明
#
# user_id	用户标识
#
# jd_no	user_id对应被曝光的简历

# %%
big_table = pd.merge(train_action,train_user,how="inner",on="user_id")
big_table = pd.merge(big_table,train_job,how="inner",on="jd_no")
big_table.head(2)
# Out:
#                             user_id                             jd_no  \
# 0  17e1b9f107dd1214bd78dec6d91593a4  4ce99de185f55bea127ccd74c4bbf0ad
# 1  17e1b9f107dd1214bd78dec6d91593a4  e9959d3b5fd8b26da07e8b8a3b80489a
#
#    browsed  delivered  satisfied  live_city_id desire_jd_city_id  \
# 0        0          0          0           551           551,-,-
# 1        0          0          0           551           551,-,-
#
#   desire_jd_industry_id desire_jd_type_id  desire_jd_salary_id  \
# 0          房地产/建筑/建材/工程          工程造价/预结算            100002000
# 1          房地产/建筑/建材/工程          工程造价/预结算            100002000
#
#   cur_industry_id    cur_jd_type cur_salary_id cur_degree_id  birthday  \
# 0    房地产/建筑/建材/工程  土木/建筑/装修/市政工程    0200104000            大专        24
# 1    房地产/建筑/建材/工程  土木/建筑/装修/市政工程    0200104000            大专        24
#
#   start_work_date                                         experience jd_title  \
# 0            2017  停车|现场|凤凰|预算编制|建设|实习|专家|公园|预算软件|勘察|合同|知识|商务|单位|...  土建工程造价员
# 1            2017  停车|现场|凤凰|预算编制|建设|实习|专家|公园|预算软件|勘察|合同|知识|商务|单位|...   招标代理人员
#
#   company_name  city jd_sub_type  require_nums  max_salary  min_salary  \
# 0            -   551    工程造价/预结算             5        8000        4000
# 1            -   551       项目招投标             3        6000        3000
#
#   start_date  end_date  is_travel  min_years  key min_edu_level max_edu_level  \
# 0   20190313  20190412          1        305  NaN           大专             \N
# 1   20190318  20190417          1         -1  NaN            \N            \N
#
#   is_mangerial resume_language_required  \
# 0           \N                      NaN
# 1           \N                      NaN
#
#                                      job_description
# 0  1、能够独立完成工程概、预、结算的编制及审核工作；2、熟悉重庆地区相关计价原则及计价文件；3...
# 1  岗位职责：1、根据招标方要求编制招标文件，负责报建等招标代理项目流程；2、负责组织现场答疑会...

# %%
big_table.min_years.unique()
# Out:
# array([ 305,   -1,    1,  103,    0,  510, 1099,  399,  599,  199,  299,
#         110])

# %%
test_big_table = pd.merge(test_action,test_user,how="inner",on="user_id")
test_big_table = pd.merge(test_big_table,train_job,how="inner",on="jd_no")
test_big_table.head(2)
# Out:
#                             user_id                             jd_no  \
# 0  035b5c8e977d2f76628d9b7edfc95323  669576ca43ff7b2b6f5bc97a3dfeda9e
# 1  035b5c8e977d2f76628d9b7edfc95323  2fc7d27894fe1776e7b76546deb8ae5d
#
#    live_city_id desire_jd_city_id   desire_jd_industry_id desire_jd_type_id  \
# 0           613           613,-,-  房地产/建筑/建材/工程,物业管理/商业中心           行政专员/助理
# 1           613           613,-,-  房地产/建筑/建材/工程,物业管理/商业中心           行政专员/助理
#
#    desire_jd_salary_id cur_industry_id    cur_jd_type cur_salary_id  \
# 0            400106000           旅游/度假  行政经理/主管/办公室主任    0400106000
# 1            400106000           旅游/度假  行政经理/主管/办公室主任    0400106000
#
#   cur_degree_id  birthday start_work_date  \
# 0            本科        27            2012
# 1            本科        27            2012
#
#                                           experience       jd_title  \
# 0  档案管理|互联网参考模型osi七层|行政主管|入库|材料|资产管理|建设|司机|处理|行政经...  行政经理/主管/办公室主任
# 1  档案管理|互联网参考模型osi七层|行政主管|入库|材料|资产管理|建设|司机|处理|行政经...           老板司机
#
#   company_name  city    jd_sub_type  require_nums  max_salary  min_salary  \
# 0            -   613  行政经理/主管/办公室主任             1        8000        6001
# 1            -   613           后勤人员             1        4000        2001
#
#   start_date  end_date  is_travel  min_years  key min_edu_level max_edu_level  \
# 0   20190214  20190316          0        305  NaN           大专             \N
# 1   20190319  20190418          0        305  NaN           中技             \N
#
#   is_mangerial resume_language_required  \
# 0           \N                      NaN
# 1           \N                      NaN
#
#                                      job_description
# 0  岗位职责：1、规划并建立公司行政管理体系，制定并完成年度行政工作计划;2、对公司行政管理成本...
# 1  技能：熟练掌握别克GL8驾驶技术，懂得车辆保养维护，熟悉长春市内道路。任职要求：给老板开车，...

# %%
#df.drop(['B', 'C'], axis=1)
#test_big_table.drop(['company_name','max_edu_level','is_mangerial','resume_language_required'],axis=1,inplace = True)
#test_big_table.drop(columns=["company_name","max_edu_level","is_mangerial","resume_language_required"],inplace=True)
test_big_table.drop(columns=["company_name","max_edu_level","is_mangerial","resume_language_required"],inplace=True)
test_big_table.head(2)
# Out:
#                             user_id                             jd_no  \
# 0  035b5c8e977d2f76628d9b7edfc95323  669576ca43ff7b2b6f5bc97a3dfeda9e
# 1  035b5c8e977d2f76628d9b7edfc95323  2fc7d27894fe1776e7b76546deb8ae5d
#
#    live_city_id desire_jd_city_id   desire_jd_industry_id desire_jd_type_id  \
# 0           613           613,-,-  房地产/建筑/建材/工程,物业管理/商业中心           行政专员/助理
# 1           613           613,-,-  房地产/建筑/建材/工程,物业管理/商业中心           行政专员/助理
#
#    desire_jd_salary_id cur_industry_id    cur_jd_type cur_salary_id  \
# 0            400106000           旅游/度假  行政经理/主管/办公室主任    0400106000
# 1            400106000           旅游/度假  行政经理/主管/办公室主任    0400106000
#
#   cur_degree_id  birthday start_work_date  \
# 0            本科        27            2012
# 1            本科        27            2012
#
#                                           experience       jd_title  city  \
# 0  档案管理|互联网参考模型osi七层|行政主管|入库|材料|资产管理|建设|司机|处理|行政经...  行政经理/主管/办公室主任   613
# 1  档案管理|互联网参考模型osi七层|行政主管|入库|材料|资产管理|建设|司机|处理|行政经...           老板司机   613
#
#      jd_sub_type  require_nums  max_salary  min_salary start_date  end_date  \
# 0  行政经理/主管/办公室主任             1        8000        6001   20190214  20190316
# 1           后勤人员             1        4000        2001   20190319  20190418
#
#    is_travel  min_years  key min_edu_level  \
# 0          0        305  NaN           大专
# 1          0        305  NaN           中技
#
#                                      job_description
# 0  岗位职责：1、规划并建立公司行政管理体系，制定并完成年度行政工作计划;2、对公司行政管理成本...
# 1  技能：熟练掌握别克GL8驾驶技术，懂得车辆保养维护，熟悉长春市内道路。任职要求：给老板开车，...

# %% [markdown]
# 如果import numpy as np写成其他名字，比如 as tp，这句也会报错
#
# 用双引号或者单引号效果一样

# %%
def extract_city(citys,index):
  city_list = citys.split(",")
  if index < len(city_list):
    city = city_list[index]
    if city != "-":
      city = int(city)
    else:
      city = -1      
  else:
    city = -1#如果没有想去的城市则返回-1
  return city
#

# %%
def exp_in_desc(exp,desc):
  if str(exp) == "nan":
    exp = ""
  exps = exp.split("|")
  num = 0
  for item in exps:
    if item in desc:
      num +=1
  return num
#想去的和经验符合数量

# %% [markdown]
# #label encoder

# %%
min_year_dict = {
    305: 4,
    -1:-1,
    1:1,
    103:2,
    0:0,
    510:7,
    1099:10,
    399:4,
    599:7,
    199:1,
    299:2,
    110:1
}
degree_dict = {
    "初中":1,
    "中技":2,
    "高中":3,
    "中专":3,
    "大专":4,
    "本科":5,
    "硕士":6,
    "博士":7,
    "EMBA":7,
    "MBA":6,
    "其他":0,
    "请选择":0,
    "\\N":0,
    "na":0
}
min_salary_dict = {
    100002000:1000,
    400106000:4001,
    0:0,
    200104000:2001,
    600108000:6001,
    800110000:8001,
    1000115000:10001,
    2500199999:25001,
    1500125000:15001,
    3500150000:35001,
    70001100000:70001,
    1000:0,
    100001150000:100001,
    2500135000:25001,
    5000170000:50001
}
max_salary_dict = {
    100002000:2000,
    400106000:6000,
    0:0,
    200104000:4000,
    600108000:8000,
    800110000:10000,
    1000115000:15000,
    2500199999:99999,
    1500125000:25000,
    3500150000:50000,
    70001100000:100000,
    1000:1000,
    100001150000:150000,
    2500135000:35000,
    5000170000:70000
}

# %% [markdown]
# #特征处理

# %%
def fe(df):
    df["desire_jd_city_1"] = df["desire_jd_city_id"].apply(partial(extract_city,index=0))
    df["desire_jd_city_2"] = df["desire_jd_city_id"].apply(partial(extract_city,index=1))
    df["desire_jd_city_3"] = df["desire_jd_city_id"].apply(partial(extract_city,index=2))
    df["desire_jd_city_num"] = df[["desire_jd_city_1","desire_jd_city_2","desire_jd_city_3"]].sum(axis=1)
    
    df["city_equal_desired_city_1"] = df["desire_jd_city_1"]==df["city"]
    df["city_equal_desired_city_2"] = df["desire_jd_city_2"]==df["city"]
    df["city_equal_desired_city_3"] = df["desire_jd_city_3"]==df["city"]
    
    df["work_years"] = 2019-df["start_work_date"].apply(lambda x : 2018 if x=="-" else int(x))
    
    
    df["desire_min_salary"] = df["desire_jd_salary_id"].apply(lambda x: min_salary_dict[x]) #label encoder
    df["desire_max_salary"] = df["desire_jd_salary_id"].apply(lambda x: max_salary_dict[x])
    df["desire_salary_diff"] = df["desire_max_salary"]-df["desire_min_salary"]
    
    df["min_years"] = df["min_years"].apply(lambda x: min_year_dict[x])
    
    df["work_years_statisfied"] = df["work_years"].astype(int) > df["min_years"]
    
    df["salary_large_than_desire"] = df["desire_min_salary"] > df["min_salary"]
    
    df["cur_salary_min"] = df["cur_salary_id"].apply(lambda x: min_salary_dict[int(x if str.isnumeric(x) else "0")])
    df["cur_salary_max"] = df["cur_salary_id"].apply(lambda x: max_salary_dict[int(x if str.isnumeric(x) else "0")])
    
    df["salary_large_than_cur"] = df["cur_salary_min"] > df["min_salary"]
    
    df["cur_degree_id"] = df["cur_degree_id"].fillna("na").apply(lambda x:degree_dict[x.strip()])
    #strip()函数可以去掉句子前后的空格,\n,\t等（换行，回车），保持句子整洁。
    
    df["job_description_len"] = df["job_description"].apply(len)
    
    df["experience_num"] = df["experience"].apply(lambda x: len(str(x).split("|")) if str(x) != "nan" else 0)#将工作经历换成了工作过的数量
    
    df["min_edu_level"] = df["min_edu_level"].fillna("na").apply(lambda x:degree_dict[x.strip()])
    exp_in_desc_num = []
    for idx, data in df.iterrows():
        exp_in_desc_num.append(exp_in_desc(data["experience"],data["job_description"]))
    df["exp_in_desc_num"] = exp_in_desc_num
    
#     "live_city_id","desire_jd_salary_id","cur_industry_id","cur_jd_type","cur_salary_id",
#          "cur_degree_id","city","jd_sub_type",
#          "max_salary","min_salary","is_travel","min_years","min_edu_level",
#          "desire_jd_city_1","desire_jd_city_2","desire_jd_city_3","work_years_statisfied"
    cross_feature_tuple = [("live_city_id","city"),("live_city_id","desire_jd_city_1"),("cur_industry_id","jd_sub_type"),
                          ("cur_jd_type","jd_sub_type"),("cur_salary_id","cur_degree_id"),("city","jd_sub_type"),
                          ("jd_sub_type","min_salary"),("jd_sub_type","max_salary"),("jd_sub_type","is_travel"),
                          ("min_years","jd_sub_type"),("jd_sub_type","require_nums")]
   #构造特征元祖
    cross_feature_names = list(feature[0]+"&"+feature[1] for feature in cross_feature_tuple)#两个字符串用&链接
    print("create cross features",cross_feature_names)
    for idx,(fa,fb) in enumerate(cross_feature_tuple):
        df[cross_feature_names[idx]] = df[fa].astype(str)+df[fb].astype(str)
    return cross_feature_names

# %%
cross_feature_names = fe(big_table)
# Out:
# create cross features ['live_city_id&city', 'live_city_id&desire_jd_city_1', 'cur_industry_id&jd_sub_type', 'cur_jd_type&jd_sub_type', 'cur_salary_id&cur_degree_id', 'city&jd_sub_type', 'jd_sub_type&min_salary', 'jd_sub_type&max_salary', 'jd_sub_type&is_travel', 'min_years&jd_sub_type', 'jd_sub_type&require_nums']

# %%
big_table.head(2)
# Out:
#                             user_id                             jd_no  \
# 0  17e1b9f107dd1214bd78dec6d91593a4  4ce99de185f55bea127ccd74c4bbf0ad
# 1  17e1b9f107dd1214bd78dec6d91593a4  e9959d3b5fd8b26da07e8b8a3b80489a
#
#    browsed  delivered  satisfied  live_city_id desire_jd_city_id  \
# 0        0          0          0           551           551,-,-
# 1        0          0          0           551           551,-,-
#
#   desire_jd_industry_id desire_jd_type_id  desire_jd_salary_id  \
# 0          房地产/建筑/建材/工程          工程造价/预结算            100002000
# 1          房地产/建筑/建材/工程          工程造价/预结算            100002000
#
#   cur_industry_id    cur_jd_type cur_salary_id  cur_degree_id  birthday  \
# 0    房地产/建筑/建材/工程  土木/建筑/装修/市政工程    0200104000              4        24
# 1    房地产/建筑/建材/工程  土木/建筑/装修/市政工程    0200104000              4        24
#
#   start_work_date                                         experience jd_title  \
# 0            2017  停车|现场|凤凰|预算编制|建设|实习|专家|公园|预算软件|勘察|合同|知识|商务|单位|...  土建工程造价员
# 1            2017  停车|现场|凤凰|预算编制|建设|实习|专家|公园|预算软件|勘察|合同|知识|商务|单位|...   招标代理人员
#
#   company_name  city jd_sub_type  require_nums  max_salary  min_salary  \
# 0            -   551    工程造价/预结算             5        8000        4000
# 1            -   551       项目招投标             3        6000        3000
#
#   start_date  end_date  is_travel  min_years  key  min_edu_level  \
# 0   20190313  20190412          1          4  NaN              4
# 1   20190318  20190417          1         -1  NaN              0
#
#   max_edu_level is_mangerial resume_language_required  \
# 0            \N           \N                      NaN
# 1            \N           \N                      NaN
#
#                                      job_description  desire_jd_city_1  \
# 0  1、能够独立完成工程概、预、结算的编制及审核工作；2、熟悉重庆地区相关计价原则及计价文件；3...               551
# 1  岗位职责：1、根据招标方要求编制招标文件，负责报建等招标代理项目流程；2、负责组织现场答疑会...               551
#
#    desire_jd_city_2  desire_jd_city_3  desire_jd_city_num  \
# 0                -1                -1                 549
# 1                -1                -1                 549
#
#    city_equal_desired_city_1  city_equal_desired_city_2  \
# 0                       True                      False
# 1                       True                      False
#
#    city_equal_desired_city_3  work_years  desire_min_salary  \
# 0                      False           2               1000
# 1                      False           2               1000
#
#    desire_max_salary  desire_salary_diff  work_years_statisfied  \
# 0               2000                1000                  False
# 1               2000                1000                   True
#
#    salary_large_than_desire  cur_salary_min  cur_salary_max  \
# 0                     False            2001            4000
# 1                     False            2001            4000
#
#    salary_large_than_cur  job_description_len  experience_num  \
# 0                  False                  121              65
# 1                  False                  288              65
#
#    exp_in_desc_num live_city_id&city live_city_id&desire_jd_city_1  \
# 0                5            551551                        551551
# 1               10            551551                        551551
#
#   cur_industry_id&jd_sub_type cur_jd_type&jd_sub_type  \
# 0        房地产/建筑/建材/工程工程造价/预结算   土木/建筑/装修/市政工程工程造价/预结算
# 1           房地产/建筑/建材/工程项目招投标      土木/建筑/装修/市政工程项目招投标
#
#   cur_salary_id&cur_degree_id city&jd_sub_type jd_sub_type&min_salary  \
# 0                 02001040004      551工程造价/预结算           工程造价/预结算4000
# 1                 02001040004         551项目招投标              项目招投标3000
#
#   jd_sub_type&max_salary jd_sub_type&is_travel min_years&jd_sub_type  \
# 0           工程造价/预结算8000             工程造价/预结算1             4工程造价/预结算
# 1              项目招投标6000                项目招投标1               -1项目招投标
#
#   jd_sub_type&require_nums
# 0                工程造价/预结算5
# 1                   项目招投标3

# %%
fe(test_big_table)
# Out:
# create cross features ['live_city_id&city', 'live_city_id&desire_jd_city_1', 'cur_industry_id&jd_sub_type', 'cur_jd_type&jd_sub_type', 'cur_salary_id&cur_degree_id', 'city&jd_sub_type', 'jd_sub_type&min_salary', 'jd_sub_type&max_salary', 'jd_sub_type&is_travel', 'min_years&jd_sub_type', 'jd_sub_type&require_nums']
# ['live_city_id&city',
#  'live_city_id&desire_jd_city_1',
#  'cur_industry_id&jd_sub_type',
#  'cur_jd_type&jd_sub_type',
#  'cur_salary_id&cur_degree_id',
#  'city&jd_sub_type',
#  'jd_sub_type&min_salary',
#  'jd_sub_type&max_salary',
#  'jd_sub_type&is_travel',
#  'min_years&jd_sub_type',
#  'jd_sub_type&require_nums']

# %%
test_big_table.head(2)
# Out:
#                             user_id                             jd_no  \
# 0  035b5c8e977d2f76628d9b7edfc95323  669576ca43ff7b2b6f5bc97a3dfeda9e
# 1  035b5c8e977d2f76628d9b7edfc95323  2fc7d27894fe1776e7b76546deb8ae5d
#
#    live_city_id desire_jd_city_id   desire_jd_industry_id desire_jd_type_id  \
# 0           613           613,-,-  房地产/建筑/建材/工程,物业管理/商业中心           行政专员/助理
# 1           613           613,-,-  房地产/建筑/建材/工程,物业管理/商业中心           行政专员/助理
#
#    desire_jd_salary_id cur_industry_id    cur_jd_type cur_salary_id  \
# 0            400106000           旅游/度假  行政经理/主管/办公室主任    0400106000
# 1            400106000           旅游/度假  行政经理/主管/办公室主任    0400106000
#
#    cur_degree_id  birthday start_work_date  \
# 0              5        27            2012
# 1              5        27            2012
#
#                                           experience       jd_title  city  \
# 0  档案管理|互联网参考模型osi七层|行政主管|入库|材料|资产管理|建设|司机|处理|行政经...  行政经理/主管/办公室主任   613
# 1  档案管理|互联网参考模型osi七层|行政主管|入库|材料|资产管理|建设|司机|处理|行政经...           老板司机   613
#
#      jd_sub_type  require_nums  max_salary  min_salary start_date  end_date  \
# 0  行政经理/主管/办公室主任             1        8000        6001   20190214  20190316
# 1           后勤人员             1        4000        2001   20190319  20190418
#
#    is_travel  min_years  key  min_edu_level  \
# 0          0          4  NaN              4
# 1          0          4  NaN              2
#
#                                      job_description  desire_jd_city_1  \
# 0  岗位职责：1、规划并建立公司行政管理体系，制定并完成年度行政工作计划;2、对公司行政管理成本...               613
# 1  技能：熟练掌握别克GL8驾驶技术，懂得车辆保养维护，熟悉长春市内道路。任职要求：给老板开车，...               613
#
#    desire_jd_city_2  desire_jd_city_3  desire_jd_city_num  \
# 0                -1                -1                 611
# 1                -1                -1                 611
#
#    city_equal_desired_city_1  city_equal_desired_city_2  \
# 0                       True                      False
# 1                       True                      False
#
#    city_equal_desired_city_3  work_years  desire_min_salary  \
# 0                      False           7               4001
# 1                      False           7               4001
#
#    desire_max_salary  desire_salary_diff  work_years_statisfied  \
# 0               6000                1999                   True
# 1               6000                1999                   True
#
#    salary_large_than_desire  cur_salary_min  cur_salary_max  \
# 0                     False            4001            6000
# 1                      True            4001            6000
#
#    salary_large_than_cur  job_description_len  experience_num  \
# 0                  False                  208              35
# 1                   True                  201              35
#
#    exp_in_desc_num live_city_id&city live_city_id&desire_jd_city_1  \
# 0                3            613613                        613613
# 1                3            613613                        613613
#
#   cur_industry_id&jd_sub_type     cur_jd_type&jd_sub_type  \
# 0          旅游/度假行政经理/主管/办公室主任  行政经理/主管/办公室主任行政经理/主管/办公室主任
# 1                   旅游/度假后勤人员           行政经理/主管/办公室主任后勤人员
#
#   cur_salary_id&cur_degree_id  city&jd_sub_type jd_sub_type&min_salary  \
# 0                 04001060005  613行政经理/主管/办公室主任      行政经理/主管/办公室主任6001
# 1                 04001060005           613后勤人员               后勤人员2001
#
#   jd_sub_type&max_salary jd_sub_type&is_travel min_years&jd_sub_type  \
# 0      行政经理/主管/办公室主任8000        行政经理/主管/办公室主任0        4行政经理/主管/办公室主任
# 1               后勤人员4000                 后勤人员0                 4后勤人员
#
#   jd_sub_type&require_nums
# 0           行政经理/主管/办公室主任1
# 1                    后勤人员1

# %%
all_big_table = pd.concat([big_table,test_big_table])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
all_big_table.head(5)
# Out:
#    birthday  browsed  city city&jd_sub_type  city_equal_desired_city_1  \
# 0        24      0.0   551      551工程造价/预结算                       True
# 1        24      0.0   551         551项目招投标                       True
# 2        21      1.0   551         551项目招投标                       True
# 3        24      0.0   551      551工程造价/预结算                       True
# 4        24      0.0   551      551工程造价/预结算                       True
#
#    city_equal_desired_city_2  city_equal_desired_city_3 company_name  \
# 0                      False                      False            -
# 1                      False                      False            -
# 2                       True                       True            -
# 3                      False                      False            -
# 4                      False                      False            -
#
#    cur_degree_id cur_industry_id cur_industry_id&jd_sub_type    cur_jd_type  \
# 0              4    房地产/建筑/建材/工程        房地产/建筑/建材/工程工程造价/预结算  土木/建筑/装修/市政工程
# 1              4    房地产/建筑/建材/工程           房地产/建筑/建材/工程项目招投标  土木/建筑/装修/市政工程
# 2              4        电气/电力/水利               电气/电力/水利项目招投标             其他
# 3              4    房地产/建筑/建材/工程        房地产/建筑/建材/工程工程造价/预结算  土木/建筑/装修/市政工程
# 4              4    房地产/建筑/建材/工程        房地产/建筑/建材/工程工程造价/预结算  土木/建筑/装修/市政工程
#
#   cur_jd_type&jd_sub_type cur_salary_id cur_salary_id&cur_degree_id  \
# 0   土木/建筑/装修/市政工程工程造价/预结算    0200104000                 02001040004
# 1      土木/建筑/装修/市政工程项目招投标    0200104000                 02001040004
# 2                 其他项目招投标    0200104000                 02001040004
# 3   土木/建筑/装修/市政工程工程造价/预结算    0200104000                 02001040004
# 4   土木/建筑/装修/市政工程工程造价/预结算    0200104000                 02001040004
#
#    cur_salary_max  cur_salary_min  delivered  desire_jd_city_1  \
# 0            4000            2001        0.0               551
# 1            4000            2001        0.0               551
# 2            4000            2001        1.0               551
# 3            4000            2001        0.0               551
# 4            4000            2001        0.0               551
#
#    desire_jd_city_2  desire_jd_city_3 desire_jd_city_id  desire_jd_city_num  \
# 0                -1                -1           551,-,-                 549
# 1                -1                -1           551,-,-                 549
# 2               551               551       551,551,551                1653
# 3                -1                -1           551,-,-                 549
# 4                -1                -1           551,-,-                 549
#
#    desire_jd_industry_id  desire_jd_salary_id    desire_jd_type_id  \
# 0           房地产/建筑/建材/工程            100002000             工程造价/预结算
# 1           房地产/建筑/建材/工程            100002000             工程造价/预结算
# 2  电气/电力/水利,房地产/建筑/建材/工程            200104000  项目招投标,前台/总机/接待,内勤人员
# 3           房地产/建筑/建材/工程            100002000             工程造价/预结算
# 4           房地产/建筑/建材/工程            100002000             工程造价/预结算
#
#    desire_max_salary  desire_min_salary  desire_salary_diff  end_date  \
# 0               2000               1000                1000  20190412
# 1               2000               1000                1000  20190417
# 2               4000               2001                1999  20190417
# 3               2000               1000                1000  20190412
# 4               2000               1000                1000  20190412
#
#    exp_in_desc_num                                         experience  \
# 0                5  停车|现场|凤凰|预算编制|建设|实习|专家|公园|预算软件|勘察|合同|知识|商务|单位|...
# 1               10  停车|现场|凤凰|预算编制|建设|实习|专家|公园|预算软件|勘察|合同|知识|商务|单位|...
# 2                1                                      责任心|适应能力|标书制作
# 3                4  停车|现场|凤凰|预算编制|建设|实习|专家|公园|预算软件|勘察|合同|知识|商务|单位|...
# 4                4  停车|现场|凤凰|预算编制|建设|实习|专家|公园|预算软件|勘察|合同|知识|商务|单位|...
#
#    experience_num is_mangerial  is_travel                             jd_no  \
# 0              65           \N          1  4ce99de185f55bea127ccd74c4bbf0ad
# 1              65           \N          1  e9959d3b5fd8b26da07e8b8a3b80489a
# 2               3           \N          1  e9959d3b5fd8b26da07e8b8a3b80489a
# 3              65           \N          0  7ecd6ab0c7e43b40b7d1dbd4a9b1e6f5
# 4              65           \N          0  112ea9c8ef92c1a7d5fa679cc6c05053
#
#   jd_sub_type jd_sub_type&is_travel jd_sub_type&max_salary  \
# 0    工程造价/预结算             工程造价/预结算1           工程造价/预结算8000
# 1       项目招投标                项目招投标1              项目招投标6000
# 2       项目招投标                项目招投标1              项目招投标6000
# 3    工程造价/预结算             工程造价/预结算0           工程造价/预结算4000
# 4    工程造价/预结算             工程造价/预结算0           工程造价/预结算4000
#
#   jd_sub_type&min_salary jd_sub_type&require_nums jd_title  \
# 0           工程造价/预结算4000                工程造价/预结算5  土建工程造价员
# 1              项目招投标3000                   项目招投标3   招标代理人员
# 2              项目招投标3000                   项目招投标3   招标代理人员
# 3           工程造价/预结算2001                工程造价/预结算1    设计师助理
# 4           工程造价/预结算2001                工程造价/预结算1    设计师助理
#
#                                      job_description  job_description_len  \
# 0  1、能够独立完成工程概、预、结算的编制及审核工作；2、熟悉重庆地区相关计价原则及计价文件；3...                  121
# 1  岗位职责：1、根据招标方要求编制招标文件，负责报建等招标代理项目流程；2、负责组织现场答疑会...                  288
# 2  岗位职责：1、根据招标方要求编制招标文件，负责报建等招标代理项目流程；2、负责组织现场答疑会...                  288
# 3  岗位职责：1.协助设计师完成方案图纸或施工图纸的绘制；2.协助设计师负责现场施工维护；3.协...                  157
# 4  岗位职责：1.协助设计师完成方案图纸或施工图纸的绘制；2.协助设计师负责现场施工维护；3.协...                  157
#
#    key  live_city_id live_city_id&city live_city_id&desire_jd_city_1  \
# 0  NaN           551            551551                        551551
# 1  NaN           551            551551                        551551
# 2  NaN           551            551551                        551551
# 3  NaN           551            551551                        551551
# 4  NaN           551            551551                        551551
#
#   max_edu_level  max_salary  min_edu_level  min_salary  min_years  \
# 0            \N        8000              4        4000          4
# 1            \N        6000              0        3000         -1
# 2            \N        6000              0        3000         -1
# 3            \N        4000              4        2001          1
# 4            \N        4000              4        2001          1
#
#   min_years&jd_sub_type  require_nums resume_language_required  \
# 0             4工程造价/预结算             5                      NaN
# 1               -1项目招投标             3                      NaN
# 2               -1项目招投标             3                      NaN
# 3             1工程造价/预结算             1                      NaN
# 4             1工程造价/预结算             1                      NaN
#
#    salary_large_than_cur  salary_large_than_desire  satisfied start_date  \
# 0                  False                     False        0.0   20190313
# 1                  False                     False        0.0   20190318
# 2                  False                     False        0.0   20190318
# 3                  False                     False        0.0   20190313
# 4                  False                     False        0.0   20190313
#
#   start_work_date                           user_id  work_years  \
# 0            2017  17e1b9f107dd1214bd78dec6d91593a4           2
# 1            2017  17e1b9f107dd1214bd78dec6d91593a4           2
# 2            2018  04edcbfd579b127171e32d7e334f9368           1
# 3            2017  17e1b9f107dd1214bd78dec6d91593a4           2
# 4            2017  17e1b9f107dd1214bd78dec6d91593a4           2
#
#    work_years_statisfied
# 0                  False
# 1                   True
# 2                   True
# 3                   True
# 4                   True

# %% [markdown]
# #Models

# %%
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm as tqdm
import lightgbm as lgb

# %%
def feature_select(target,*df_list):
    result = []
    cat_features = ["live_city_id","desire_jd_salary_id","cur_industry_id","cur_jd_type","cur_salary_id",
         "cur_degree_id","city","jd_sub_type",
         "max_salary","min_salary","is_travel","min_years","min_edu_level",
         "desire_jd_city_1","desire_jd_city_2","desire_jd_city_3","work_years_statisfied"]+cross_feature_names
    lbl_dict = {}
    for f in cat_features:
        lbl = LabelEncoder()
        lbl.fit(all_big_table[f].astype(str))
        lbl_dict[f] = lbl
    for df in df_list:
        features = ["live_city_id","desire_jd_salary_id","cur_industry_id","cur_jd_type","cur_salary_id",
             "cur_degree_id","birthday","city","jd_sub_type","require_nums",
             "max_salary","min_salary","is_travel","min_years","min_edu_level",
             "desire_jd_city_1","desire_jd_city_2","desire_jd_city_3","exp_in_desc_num",
                   "city_equal_desired_city_1","city_equal_desired_city_2","city_equal_desired_city_3",
                   "desire_min_salary","desire_max_salary","salary_large_than_desire","cur_salary_min",
                   "cur_salary_max","salary_large_than_cur","job_description_len","experience_num","work_years_statisfied","work_years","desire_jd_city_num","desire_salary_diff"]+cross_feature_names

        x = df[features]
        if target in df.columns:
            y = df[target]
        else:
            y = None
        for f in cat_features:
            lbl = lbl_dict[f]
            x[f] = lbl.transform(x[f].astype(str))
        result.append((x,y))
    return result

# %%
from sklearn.model_selection import KFold

def cross_validate(param=dict(n_estimators=1000,metric="map",colsample_bytree=0.2,max_depth=7,importance_type="gain")
                   ,n_folds=5,target="satisfied"):
    train_users = big_table["user_id"].unique()
    folds = KFold(n_folds,shuffle=True,random_state=42)
    models = []
    test_pred = np.zeros(test_big_table.shape[0])
    scores = []
    for idx,(train_idx,valid_idx) in enumerate(folds.split(train_users)):
        t_user = train_users[train_idx]
        v_user = train_users[valid_idx]
        train_data = big_table[big_table["user_id"].isin(t_user)]
        valid_data = big_table[big_table["user_id"].isin(v_user)]
        train_group = train_data.groupby("user_id",as_index=False).count()["satisfied"].values
        valid_group = valid_data.groupby("user_id",as_index=False).count()["satisfied"].values
        test_group = test_big_table.groupby("user_id",as_index=False).count()["jd_no"].values
        
        result = feature_select(target,train_data,valid_data,test_big_table)
        t_x,t_y = result[0]
        v_x,v_y = result[1]
        test_x,_ = result[2]
        model = lgb.LGBMRanker(**param)
        print("Fold",idx,"-"*30)
        model.fit(t_x,t_y,group=train_group,eval_set=[(t_x,t_y),(v_x,v_y)],eval_group=[train_group,valid_group],early_stopping_rounds=100,verbose=10,
                  callbacks=[lgb.reset_parameter(learning_rate=lambda x: 0.01)]
                 )
        models.append(model)
        test_pred += model.predict(test_x)/n_folds
        scores.append(model.best_score_["valid_1"]["map@1"])
    print("mean score",np.mean(scores))
    return models,test_pred

# %%
models,pred = cross_validate(target="satisfied",param=dict(n_estimators=1000,metric="map",subsample=0.8,min_split_gain=10,colsample_bytree=0.8,max_depth=2,importance_type="gain"),n_folds=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fold 0 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.226641	valid_1's map@1: 0.228031
# [20]	training's map@1: 0.2297	valid_1's map@1: 0.234705
# [30]	training's map@1: 0.236652	valid_1's map@1: 0.246941
# [40]	training's map@1: 0.236374	valid_1's map@1: 0.248053
# [50]	training's map@1: 0.238598	valid_1's map@1: 0.249166
# [60]	training's map@1: 0.238598	valid_1's map@1: 0.248053
# [70]	training's map@1: 0.239155	valid_1's map@1: 0.249166
# [80]	training's map@1: 0.238877	valid_1's map@1: 0.250278
# [90]	training's map@1: 0.238877	valid_1's map@1: 0.249166
# [100]	training's map@1: 0.25139	valid_1's map@1: 0.258065
# [110]	training's map@1: 0.252503	valid_1's map@1: 0.256952
# [120]	training's map@1: 0.253893	valid_1's map@1: 0.256952
# [130]	training's map@1: 0.253893	valid_1's map@1: 0.258065
# [140]	training's map@1: 0.253059	valid_1's map@1: 0.258065
# [150]	training's map@1: 0.255284	valid_1's map@1: 0.253615
# [160]	training's map@1: 0.256118	valid_1's map@1: 0.253615
# [170]	training's map@1: 0.256396	valid_1's map@1: 0.253615
# [180]	training's map@1: 0.256118	valid_1's map@1: 0.253615
# [190]	training's map@1: 0.256396	valid_1's map@1: 0.253615
# Early stopping, best iteration is:
# [97]	training's map@1: 0.250556	valid_1's map@1: 0.259177
# Fold 1 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.236374	valid_1's map@1: 0.20356
# [20]	training's map@1: 0.244994	valid_1's map@1: 0.213571
# [30]	training's map@1: 0.243604	valid_1's map@1: 0.214683
# [40]	training's map@1: 0.240545	valid_1's map@1: 0.216908
# [50]	training's map@1: 0.246385	valid_1's map@1: 0.221357
# [60]	training's map@1: 0.245551	valid_1's map@1: 0.221357
# [70]	training's map@1: 0.246107	valid_1's map@1: 0.221357
# [80]	training's map@1: 0.245829	valid_1's map@1: 0.221357
# [90]	training's map@1: 0.246107	valid_1's map@1: 0.221357
# [100]	training's map@1: 0.245829	valid_1's map@1: 0.220245
# [110]	training's map@1: 0.245829	valid_1's map@1: 0.220245
# [120]	training's map@1: 0.25	valid_1's map@1: 0.228031
# [130]	training's map@1: 0.25	valid_1's map@1: 0.229143
# [140]	training's map@1: 0.250278	valid_1's map@1: 0.226919
# [150]	training's map@1: 0.249444	valid_1's map@1: 0.228031
# Early stopping, best iteration is:
# [52]	training's map@1: 0.250278	valid_1's map@1: 0.216908
# Fold 2 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.224972	valid_1's map@1: 0.223582
# [20]	training's map@1: 0.226641	valid_1's map@1: 0.230256
# [30]	training's map@1: 0.223304	valid_1's map@1: 0.226919
# [40]	training's map@1: 0.229422	valid_1's map@1: 0.226919
# [50]	training's map@1: 0.230812	valid_1's map@1: 0.239155
# [60]	training's map@1: 0.231368	valid_1's map@1: 0.242492
# [70]	training's map@1: 0.233315	valid_1's map@1: 0.243604
# [80]	training's map@1: 0.232481	valid_1's map@1: 0.243604
# [90]	training's map@1: 0.232481	valid_1's map@1: 0.243604
# [100]	training's map@1: 0.241101	valid_1's map@1: 0.248053
# [110]	training's map@1: 0.241657	valid_1's map@1: 0.249166
# [120]	training's map@1: 0.242492	valid_1's map@1: 0.250278
# [130]	training's map@1: 0.242492	valid_1's map@1: 0.25139
# [140]	training's map@1: 0.243604	valid_1's map@1: 0.252503
# [150]	training's map@1: 0.243604	valid_1's map@1: 0.25139
# [160]	training's map@1: 0.246107	valid_1's map@1: 0.249166
# [170]	training's map@1: 0.246107	valid_1's map@1: 0.249166
# [180]	training's map@1: 0.245829	valid_1's map@1: 0.250278
# [190]	training's map@1: 0.247219	valid_1's map@1: 0.249166
# [200]	training's map@1: 0.248053	valid_1's map@1: 0.248053
# [210]	training's map@1: 0.247219	valid_1's map@1: 0.248053
# [220]	training's map@1: 0.247775	valid_1's map@1: 0.248053
# [230]	training's map@1: 0.247497	valid_1's map@1: 0.248053
# [240]	training's map@1: 0.252225	valid_1's map@1: 0.252503
# [250]	training's map@1: 0.251669	valid_1's map@1: 0.252503
# [260]	training's map@1: 0.251947	valid_1's map@1: 0.253615
# [270]	training's map@1: 0.251669	valid_1's map@1: 0.253615
# [280]	training's map@1: 0.256118	valid_1's map@1: 0.25584
# [290]	training's map@1: 0.257508	valid_1's map@1: 0.256952
# [300]	training's map@1: 0.25723	valid_1's map@1: 0.258065
# [310]	training's map@1: 0.257508	valid_1's map@1: 0.25584
# [320]	training's map@1: 0.256396	valid_1's map@1: 0.258065
# [330]	training's map@1: 0.256674	valid_1's map@1: 0.25584
# [340]	training's map@1: 0.256952	valid_1's map@1: 0.258065
# [350]	training's map@1: 0.256674	valid_1's map@1: 0.258065
# [360]	training's map@1: 0.258621	valid_1's map@1: 0.252503
# [370]	training's map@1: 0.261958	valid_1's map@1: 0.252503
# [380]	training's map@1: 0.261958	valid_1's map@1: 0.253615
# [390]	training's map@1: 0.261958	valid_1's map@1: 0.252503
# Early stopping, best iteration is:
# [291]	training's map@1: 0.257508	valid_1's map@1: 0.258065
# Fold 3 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.236652	valid_1's map@1: 0.220245
# [20]	training's map@1: 0.235818	valid_1's map@1: 0.220245
# [30]	training's map@1: 0.241101	valid_1's map@1: 0.226919
# [40]	training's map@1: 0.240823	valid_1's map@1: 0.228031
# [50]	training's map@1: 0.241935	valid_1's map@1: 0.229143
# [60]	training's map@1: 0.24277	valid_1's map@1: 0.229143
# [70]	training's map@1: 0.243048	valid_1's map@1: 0.229143
# [80]	training's map@1: 0.243326	valid_1's map@1: 0.229143
# [90]	training's map@1: 0.256952	valid_1's map@1: 0.234705
# [100]	training's map@1: 0.257508	valid_1's map@1: 0.23693
# [110]	training's map@1: 0.257786	valid_1's map@1: 0.23693
# [120]	training's map@1: 0.259455	valid_1's map@1: 0.235818
# [130]	training's map@1: 0.259733	valid_1's map@1: 0.233593
# [140]	training's map@1: 0.259177	valid_1's map@1: 0.233593
# [150]	training's map@1: 0.260289	valid_1's map@1: 0.234705
# [160]	training's map@1: 0.259733	valid_1's map@1: 0.234705
# [170]	training's map@1: 0.260011	valid_1's map@1: 0.233593
# [180]	training's map@1: 0.260567	valid_1's map@1: 0.233593
# Early stopping, best iteration is:
# [87]	training's map@1: 0.251112	valid_1's map@1: 0.23693
# Fold 4 ------------------------------
# Training until validation scores don't improve for 100 rounds.
# [10]	training's map@1: 0.231368	valid_1's map@1: 0.220245
# [20]	training's map@1: 0.233871	valid_1's map@1: 0.216908
# [30]	training's map@1: 0.233593	valid_1's map@1: 0.216908
# [40]	training's map@1: 0.233037	valid_1's map@1: 0.216908
# [50]	training's map@1: 0.233315	valid_1's map@1: 0.219132
# [60]	training's map@1: 0.233315	valid_1's map@1: 0.220245
# [70]	training's map@1: 0.234705	valid_1's map@1: 0.223582
# [80]	training's map@1: 0.235261	valid_1's map@1: 0.223582
# [90]	training's map@1: 0.235261	valid_1's map@1: 0.223582
# [100]	training's map@1: 0.235818	valid_1's map@1: 0.223582
# [110]	training's map@1: 0.235818	valid_1's map@1: 0.223582
# Early stopping, best iteration is:
# [12]	training's map@1: 0.235818	valid_1's map@1: 0.216908
# mean score 0.23759733036707456

# %%
import matplotlib.pyplot as plt
import seaborn as sns

feature_importance = pd.DataFrame()
for idx,model in enumerate(models):
    fold_importance = pd.DataFrame()
    fold_importance["feature"] = ["live_city_id","desire_jd_salary_id","cur_industry_id","cur_jd_type","cur_salary_id",
             "cur_degree_id","birthday","city","jd_sub_type","require_nums",
             "max_salary","min_salary","is_travel","min_years","min_edu_level",
             "desire_jd_city_1","desire_jd_city_2","desire_jd_city_3","exp_in_desc_num",
                   "city_equal_desired_city_1","city_equal_desired_city_2","city_equal_desired_city_3",
                   "desire_min_salary","desire_max_salary","salary_large_than_desire","cur_salary_min",
                   "cur_salary_max","salary_large_than_cur","job_description_len","experience_num","work_years_statisfied","work_years","desire_jd_city_num","desire_salary_diff"]+cross_feature_names
    fold_importance["importance"] = model.feature_importances_
    fold_importance["fold"] = idx
    feature_importance = pd.concat([feature_importance,fold_importance])
plt.figure(figsize=(13, 9));
sns.barplot(x="importance", y="feature", data=feature_importance.sort_values(by="importance", ascending=False));
plt.title('satisfied LGB Features (avg over folds)');

# %%
submit = test_big_table[["user_id","jd_no"]]
submit["score"] = pred
submit = submit.reset_index(drop=True)
result = pd.merge(test_action,submit,how="left",on=["user_id","jd_no"])
result.fillna(-100,inplace=True)
result = result.groupby("user_id",as_index=False).apply(lambda x:x.sort_values("score",ascending=False))
# 需要对结果进行去重
result[["user_id","jd_no"]].drop_duplicates().to_csv("submission.csv",index=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
